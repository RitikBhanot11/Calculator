# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#   Seller ID  Seller Rating Seller Country Seller City  Total Listings  \
# 0      S063            3.4         Latvia        Riga             189
# 1      S007            4.1         Poland      Warsaw             184
# 2      S088            3.6        Estonia     Tallinn              56
# 3      S138            3.2        Estonia     Tallinn              97
# 4      S075            5.0      Lithuania      Kaunas              60
#
#   Product ID              Product Name   Brand Category Size Condition  Color  \
# 0      P0001  Adidas Essentials Hoodie  Adidas    Shoes   42       New  Green
# 1      P0002        H&M Cotton T-Shirt     H&M  T-Shirt   42      Fair  White
# 2      P0003  Nike Air Max 90 Sneakers    Nike    Dress   XS       New    Red
# 3      P0004     Levi's 501 Blue Jeans  Levi's    Shoes   XL      Good   Gray
# 4      P0005  Adidas Essentials Hoodie  Adidas    Shoes    L      Good    Red
#
#     Material  Gender   Price
# 0  Polyester     Men    9.32
# 1  Polyester  Unisex   45.34
# 2     Cotton   Women  127.89
# 3       Wool   Women   88.72
# 4    Leather     Men   58.68

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Seller ID       1000 non-null   object
#  1   Seller Rating   1000 non-null   float64
#  2   Seller Country  1000 non-null   object
#  3   Seller City     1000 non-null   object
#  4   Total Listings  1000 non-null   int64
#  5   Product ID      1000 non-null   object
#  6   Product Name    901 non-null    object
#  7   Brand           1000 non-null   object
#  8   Category        1000 non-null   object
#  9   Size            1000 non-null   object
#  10  Condition       1000 non-null   object
#  11  Color           1000 non-null   object
#  12  Material        1000 non-null   object
#  13  Gender          1000 non-null   object
#  14  Price           900 non-null    float64
# dtypes: float64(2), int64(1), object(12)
# memory usage: 117.3+ KB

# %%
df.describe()
# Out:
#        Seller Rating  Total Listings       Price
# count    1000.000000     1000.000000  900.000000
# mean        3.972100      105.098000   75.697744
# std         0.585623       56.098105   42.000319
# min         3.000000        1.000000    5.210000
# 25%         3.400000       56.000000   39.237500
# 50%         4.000000      107.000000   76.435000
# 75%         4.500000      153.250000  109.417500
# max         5.000000      200.000000  149.860000

# %%
df.isnull().sum()
# Out:
# Seller ID           0
# Seller Rating       0
# Seller Country      0
# Seller City         0
# Total Listings      0
# Product ID          0
# Product Name       99
# Brand               0
# Category            0
# Size                0
# Condition           0
# Color               0
# Material            0
# Gender              0
# Price             100
# dtype: int64

# %%
df["Price"] = df.groupby('Category')["Price"].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Seller ID          0
# Seller Rating      0
# Seller Country     0
# Seller City        0
# Total Listings     0
# Product ID         0
# Product Name      99
# Brand              0
# Category           0
# Size               0
# Condition          0
# Color              0
# Material           0
# Gender             0
# Price              0
# dtype: int64

# %%
df["product_name"].unique()
# Out:
# array(['Adidas Essentials Hoodie', 'H&M Cotton T-Shirt',
#        'Nike Air Max 90 Sneakers', "Levi's 501 Blue Jeans",
#        'H&M Denim Jacket', "Levi's Classic Jeans", 'Nike Running Shoes',
#        'Uniqlo HeatTech Shirt', 'Adidas Training T-Shirt',
#        'Zara Floral Summer Dress', 'Uniqlo Relaxed Jeans',
#        'H&M Basic Hoodie', 'Zara Casual Jacket', 'Nike Sports Hoodie',
#        'Puma Sports T-Shirt', 'Tommy Hilfiger Logo Hoodie',
#        'Puma Zip Hoodie', 'Puma Running Shoes', 'Adidas Ultraboost Shoes',
#        'Uniqlo Cotton Hoodie', 'Tommy Hilfiger Premium Jacket',
#        "Levi's Denim Jacket", 'Tommy Hilfiger Slim Jeans',
#        'Zara Slim Fit Jeans'], dtype=object)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Seller ID         0
# Seller Rating     0
# Seller Country    0
# Seller City       0
# Total Listings    0
# Product ID        0
# Product Name      0
# Brand             0
# Category          0
# Size              0
# Condition         0
# Color             0
# Material          0
# Gender            0
# Price             0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['seller_id', 'seller_rating', 'seller_country', 'seller_city',
#        'total_listings', 'product_id', 'product_name', 'brand', 'category',
#        'size', 'condition', 'color', 'material', 'gender', 'price'],
#       dtype='object')
